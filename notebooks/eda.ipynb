# %%
import pandas as pd
import numpy as np
import pygeohash as pgh
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)

# %%
import os
print(os.getcwd())
# Out:
# /home/shivamkumar/Projects/gridlock-hackathon/notebooks

# %%
train_df = pd.read_csv("../data/raw/train.csv")
test_df = pd.read_csv("../data/raw/test.csv")

print(train_df.shape)
print(test_df.shape)

train_df.head()
# Out:
# (77299, 11)
# (41778, 10)
#    Index geohash  day timestamp    demand     RoadType  NumberofLanes  \
# 0      0  qp02z1   48       0:0  0.048804          NaN              1
# 1      1  qp02zt   48       0:0  0.118507  Residential              3
# 2      2  qp08bj   48       0:0  0.027132  Residential              1
# 3      3  qp08gt   48       0:0  0.003272  Residential              1
# 4      4  qp02zq   48       0:0  0.010819  Residential              1
#
#   LargeVehicles Landmarks  Temperature Weather
# 0   Not Allowed        No          NaN     NaN
# 1       Allowed       Yes    31.104565   Sunny
# 2   Not Allowed        No    25.919267   Sunny
# 3   Not Allowed        No          NaN   Rainy
# 4   Not Allowed        No    10.803667   Rainy

# %%
train_df.info()

train_df.describe(include='all')
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 77299 entries, 0 to 77298
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          77299 non-null  int64
#  1   geohash        77299 non-null  str
#  2   day            77299 non-null  int64
#  3   timestamp      77299 non-null  str
#  4   demand         77299 non-null  float64
#  5   RoadType       76699 non-null  str
#  6   NumberofLanes  77299 non-null  int64
#  7   LargeVehicles  77299 non-null  str
#  8   Landmarks      77299 non-null  str
#  9   Temperature    74804 non-null  float64
#  10  Weather        76502 non-null  str
# dtypes: float64(2), int64(3), str(6)
# memory usage: 6.5 MB
#                Index geohash           day timestamp        demand  \
# count   77299.000000   77299  77299.000000     77299  7.729900e+04
# unique           NaN    1249           NaN        96           NaN
# top              NaN  qp094q           NaN       2:0           NaN
# freq             NaN     105           NaN      1778           NaN
# mean    38649.000000     NaN     48.101838       NaN  9.394238e-02
# std     22314.443566     NaN      0.302438       NaN  1.421905e-01
# min         0.000000     NaN     48.000000       NaN  6.245650e-07
# 25%     19324.500000     NaN     48.000000       NaN  1.822723e-02
# 50%     38649.000000     NaN     48.000000       NaN  4.775994e-02
# 75%     57973.500000     NaN     48.000000       NaN  1.085951e-01
# max     77298.000000     NaN     49.000000       NaN  1.000000e+00
#
#            RoadType  NumberofLanes LargeVehicles Landmarks   Temperature  \
# count         76699   77299.000000         77299     77299  74804.000000
# unique            3            NaN             2         2           NaN
# top     Residential            NaN   Not Allowed       Yes           NaN
# freq          69230            NaN         50673     52042           NaN
# mean            NaN       2.014334           NaN       NaN     16.405354
# std             NaN       0.904665           NaN       NaN      7.359835
# min             NaN       1.000000           NaN       NaN    -14.935097
# 25%             NaN       1.000000           NaN       NaN     11.430473
# 50%             NaN       2.000000           NaN       NaN     16.382587
# 75%             NaN       3.000000           NaN       NaN     21.298833
# max             NaN       5.000000           NaN       NaN     48.251433
#
#        Weather
# count    76502
# unique       4
# top      Sunny
# freq     27717
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
missing = train_df.isnull().sum()

missing[missing > 0].sort_values(ascending=False)
# Out:
# Temperature    2495
# Weather         797
# RoadType        600
# dtype: int64

# %%
train_df['demand'].describe()
# Out:
# count    7.729900e+04
# mean     9.394238e-02
# std      1.421905e-01
# min      6.245650e-07
# 25%      1.822723e-02
# 50%      4.775994e-02
# 75%      1.085951e-01
# max      1.000000e+00
# Name: demand, dtype: float64

# %%
plt.figure(figsize=(8,4))

plt.hist(
    train_df['demand'],
    bins=50
)

plt.xlabel("Demand")
plt.ylabel("Frequency")
plt.title("Demand Distribution")

plt.show()

plt.figure(figsize=(10,2))

plt.boxplot(
    train_df['demand'],
    vert=False
)

plt.show()

train_df['demand'].skew()
# Out:
# np.float64(3.7285172887316627)

# %%
train_df['day'].value_counts().sort_index()
sorted(train_df['day'].unique())
# Out:
# [np.int64(48), np.int64(49)]

# %%
train_df['geohash'].nunique()
# Out:
# 1249

# %%
train_df['geohash'].value_counts().head(20)
# Out:
# geohash
# qp094q    105
# qp03pr    105
# qp094r    105
# qp03r0    105
# qp03r2    105
# qp03q9    105
# qp03r1    105
# qp03r3    105
# qp03r9    105
# qp03qd    105
# qp03qf    105
# qp03mg    105
# qp03qg    105
# qp03r5    105
# qp0927    105
# qp097e    105
# qp092h    105
# qp092k    105
# qp096u    105
# qp097s    105
# Name: count, dtype: int64

# %%
vc = train_df['geohash'].value_counts()

plt.hist(
    vc,
    bins=105
)

plt.xlabel("Occurrences")
plt.ylabel("Number of Geohashes")

plt.show()

# %%
train_df['RoadType'].value_counts()
# Out:
# RoadType
# Residential    69230
# Street          3909
# Highway         3560
# Name: count, dtype: int64

# %%
train_df['RoadType'].value_counts(normalize=True) * 100
# Out:
# RoadType
# Residential    90.261933
# Street          5.096546
# Highway         4.641521
# Name: proportion, dtype: float64

# %%
road_stats = (
    train_df
    .groupby('RoadType')['demand']
    .describe()
)

road_stats
# Out:
#                count      mean       std           min       25%       50%  \
# RoadType
# Highway       3560.0  0.610756  0.229419  3.500089e-01  0.413629  0.526432
# Residential  69230.0  0.057209  0.052057  6.245650e-07  0.016203  0.040517
# Street        3909.0  0.273164  0.036693  2.200159e-01  0.240702  0.268124
#
#                   75%       max
# RoadType
# Highway      0.790095  1.000000
# Residential  0.084468  0.219997
# Street       0.301890  0.349908

# %%
train_df.boxplot(
    column='demand',
    by='RoadType',
    figsize=(8,4)
)

plt.suptitle("")
plt.show()

# %%
def correlation_ratio(categories, measurements):

    categories = np.array(categories)
    measurements = np.array(measurements)

    cat_codes = pd.Categorical(categories).codes

    grand_mean = measurements.mean()

    ss_between = 0

    for cat in np.unique(cat_codes):

        vals = measurements[cat_codes == cat]

        ss_between += (
            len(vals)
            * (vals.mean() - grand_mean)**2
        )

    ss_total = (
        (measurements - grand_mean)**2
    ).sum()

    return np.sqrt(
        ss_between / ss_total
    )

# %%
eta = correlation_ratio(
    train_df['geohash'],
    train_df['demand']
)

print(eta)
# Out:
# 0.8332639714109061

# %%
geo_map = {
    gh: pgh.decode(gh)
    for gh in train_df['geohash'].unique()
}

train_df['lat'] = train_df['geohash'].map(
    lambda x: geo_map[x][0]
)

train_df['lon'] = train_df['geohash'].map(
    lambda x: geo_map[x][1]
)

# %%
train_df[
    ['lat','lon','demand']
].corr()
# Out:
#              lat       lon    demand
# lat     1.000000  0.115822 -0.039219
# lon     0.115822  1.000000 -0.006807
# demand -0.039219 -0.006807  1.000000

# %%
geo_avg = (
    train_df
    .groupby('geohash')['demand']
    .mean()
)

pred = train_df['geohash'].map(
    geo_avg
)

rmse = np.sqrt(
    ((train_df['demand'] - pred)**2)
    .mean()
)

print(rmse)
# Out:
# 0.07861312870689148

# %%
road_avg = (
    train_df
    .groupby('RoadType')['demand']
    .mean()
)

pred = train_df['RoadType'].map(
    road_avg
)

rmse = np.sqrt(
    ((train_df['demand'] - pred)**2)
    .mean()
)

print(rmse)
# Out:
# 0.07040516669586941

# %%
pred = (
    train_df
    .groupby(
        ['RoadType','geohash']
    )['demand']
    .transform('mean')
)

rmse = np.sqrt(
    (
        (train_df['demand'] - pred)**2
    ).mean()
)

print(rmse)
# Out:
# 0.048331640200270067
